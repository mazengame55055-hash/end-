# %% [markdown]
# # IPTV Bot on Colab

# %%
# !git clone https://github.com/mazengame55055-hash/end-.git%cd end-!npm install

# %%
import os, subprocess, timeos.environ['TOKEN'] = 'YOUR_TOKEN_HERE'proc = subprocess.Popen(['npm', 'start'], cwd='/content/end-', env={**os.environ})print('Bot started!')while True:    time.sleep(5)    if proc.poll() is not None:        print('Bot crashed, restarting...')        proc = subprocess.Popen(['npm', 'start'], cwd='/content/end-', env={**os.environ})
