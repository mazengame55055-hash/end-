# %% [markdown]
# # تشغيل بوت IPTV على Colab

# %%
# !git clone https://github.com/mazengame55055-hash/end-.git
# %cd end-
# !npm install

# %%
import os, subprocess, threading, time

# حط التوكن هنا
os.environ['TOKEN'] = 'YOUR_TOKEN_HERE'  # ← حط التوكن بتاعك هنا

# تشغيل البوت
proc = subprocess.Popen(['npm', 'start'], cwd='/content/end-', env={**os.environ})
print('✅ البوت شغال!')

# عشان يفضل شغال
while True:
    time.sleep(10)
    if proc.poll() is not None:
        print('⚠️ البوت طاف، إعادة تشغيل...')
        proc = subprocess.Popen(['npm', 'start'], cwd='/content/end-', env={**os.environ})

# %% [markdown]
# ## ملاحظات
# - **Colab يطفي بعد 12 ساعة** - يحتاج رن تاني
# - لو عايزه يشتغل 24/7 استخدم **Fly.io** أو **Railway** أو **VPS**
